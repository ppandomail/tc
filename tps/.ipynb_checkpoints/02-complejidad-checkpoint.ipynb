# %% [markdown]
# # TP Complejidad
# ---

# %% [markdown]
# ## Determinar complejidad espacial y temporal

# %% [markdown]
# $L = \{wcw^{-1} / w \in \Sigma^*\}$

# %% [markdown]
# $f((ab)^n) = (ab)^{n+1}$
