# %% [markdown]
# # Introducción
# ---

# %% [markdown]
# ## Contexto

# %% [markdown]
# * Entender cuanto tardará una computadora en resolver un determinado problema
# * Conocer que tipo de problemas son resolubles con un determinado modelo de computador (por ej. una máquina de Turing) en un tiempo razonable (que llamaremos P) y que problemas necesitán mucho más tiempo para su resolución (problemas NP) o incluso aquellos que no son resolubles con un determinado modelo de computador
# * Presentar diferentes modelos de computadores distintos a los tradicionales como las máquinas de acceso aleatorio, las funciones recursivas, o el cálculo lambda

# %% [markdown]
# ## Ciencia

# %% [markdown]
# * Es un conjunto sistematizado de conocimientos que constituyen una rama del saber humano (geografía, biología, física, etc)
# * En sus bases, **cada ciencia posee un conjunto de inquietudes fundamentales**, como cuál es el origen de la vida orgánica, o como está conformado el universo
# * Los científicos de cada área intentan solucionar diversos problemas que nos brindan paulatinamente el conocimiento que estas inquietudes motivan descubrir

# %% [markdown]
# ## Ciencia de la computación

# %% [markdown]
# * La Ciencia de la Computación no es la excepción y posee su propio conjunto de motivaciones fundamentales. Entre ellas:
#     1. **¿Qué es un algoritmo?**
#     1. **¿Qué puede ser computado y qué no?**
#     1. **¿Cómo realizar cómputos eficientemente?**
# * Por más de sesenta años, varios científicos han tratado de responder a estas preguntas, y produjeron ingeniosas respuestas que impactaron en las Ciencias de la Computación
# * En esta materia veremos varios formalismos que surgieron como respuesta a estas preguntas

# %% [markdown]
# ## Modelos de computación

# %% [markdown]
# * Es un modelo abstracto que describe una forma de computar
# * Los aspectos a considerar al definir un modelo de computación son:
#     * ¿Cómo se representan las entradas?
#     * ¿Cómo se representan las salidas?
#     * ¿Cuáles son las operaciones elementales?
#     * ¿Cómo se combinan las operaciones para desarrollar el "programa"?

# %% [markdown]
# ## Tipos de Modelos de computación

# %% [markdown]
# * Autómatas Finitos
# * Autómatas de Pila
# * Máquinas de Turing
# * Funciones recursivas parciales
# * Máquina de Post
# * Cálculo lambda
# * Autómatas celulares
# * Computadores cuánticos

# %% [markdown]
# ## Computar

# %% [markdown]
# * Se define computar como realizar un **cálculo matemático** por medio de un conjunto finito de operaciones elementales
# * A finales del s:XIX los matemáticos comenzaron a plantearse no solo "qué calcular" o "qué propiedades tienen las cosas que calculamos" bsino "cómo calcularlo"
# * Denominamos **algoritmo o programa** a la secuencia de operaciones que permite realizar el cálculo

# %% [markdown]
# ## Computabilidad

# %% [markdown]
# * También llamada Teoría de la Computación
# * Es una rama de la Matemática que estudia las propiedades de los modelos de computación
# * En particular, la Computabilidad afronta cuestiones como:
#     * ¿Qué funciones se pueden calcular con un determinado modelo?
#     * ¿Qué funciones NO se pueden calcular con un determinado modelo?
#     * ¿Qué complejidad computacional (en tiempo o en espacio) tiene la solución de un determinado problema en un determinado modelo?
#     * ¿Qué tipos de problemas hay en función de su posible solución por medio de modelos de computación?
#     * ¿Son equivalentes dos modelos de computación?

# %% [markdown]
# ### La teoría clásica de la Computación se centra en el cálculo de funciones definidas sobre número naturales

# %% [markdown]
# ## Personajes

# %% [markdown]
# ||||
# | -- | -- | -- |
# | 1845-1918 | **Georg Cantor**             | Teoría de Conjuntos. Existencia de diferentes tipos de números infinitos (transfinitos) |
# | 1858-1932 | **Giussepe Peano**           | Lógica matemática. Axiomatización de las matemáticas   |
# | 1872-1970 | **Bertrand Russell**         | Sistema axiomático en el cual todas matemáticas pueden ser fundadas |
# | 1862-1943 | **David Hilbert**            | Problema de la decisión (entscheidungsproblem) que pretendía encontrar un algoritmo general que decidiera si una fórmula del cálculo de primer orden es un teorema |
# | 1908-1978 | **Kurt Gödel**               | Teorema de la incompletitud, que establece que para todo sistema axiomático recursivo auto-consistente lo suficientemente poderoso como para describir la aritmética de los números naturales (la aritmética de Peano)|
# | 1889-1942 | **Moses Ilyich Schönfinkel** | Lógica combinatoria                                                 |
# | 1908-1978 | **Alonzo Church**            | Cálculo lambda. Tesis de Church-Turing                              |
# | 1912-1954 | **Alan Turing**              | Los números computables, con una aplicación al Entscheidungsproblem |
# | 1900-1982 | **Haskell B. Curry**         | Lógica Combinatoria como fundamento de las Matemáticas              |
# | 1909-1994 | **Stephen Kleene**           | Cálculo lambda. Teoría de la recursión. Teoría de autómatas         |
# | 1939-     | **Stephen A. Cook**          | Teoría de la Complejidad Computacional                              |
# | 1948-     | **Leonid Levin**             | Existencia de problemas NP-completos                                |

# %% [markdown]
# ### Gracias a ellos (y también a muchos otros investigadores) existen hoy en día las Ciencias de la Computación...

# %% [markdown]
# ![investigadores.png](attachment:474969aa-a6ef-4c5b-bc89-68ad184003c2.png)

# %% [markdown]
# ## Reflexionemos un poco ...

# %% [markdown]
# * Se estima que existen 2 millones de millones de galaxias
# * Nuestra galaxia, la Via Láctea: Entre 150.000.000.000 y 250.000.000.000 de estrellas
# * El Sol: nuestra estrella

# %% [markdown]
# ## Reflexionemos un poco más ...

# %% [markdown]
# * El Universo ha llamado la atención a la humanidad desde hace miles de años
# * **Los seres humanos fuimos desarrollando diferentes teorías para explicar cómo funcionaba el Universo y qué abarcaba exactamente**
# * Muchas teorías fueron consolidándose en los últimos siglos (ejemplo: los planetas giran alrededor del Sol o más genéricamente, en torno a una estrella)
# * En todos los casos, quienes estudiaban el Universo buscaban **REGULARIDADES (patrones)** que ayudaran a entender qué sucedía
# * Las regularidades permiten construir **MODELOS** y **TEORÍAS** sobre el mundo
# * Ejemplo: Comportamiento del Cometa Halley
# * Ejemplo: Predicción de los eclipses

# %% [markdown]
# ## Las teorías pueden refinarse ...

# %% [markdown]
# |             |                       |                                                                                               |
# | --          | --                    | --                                                                                            |
# | 100 - 170   | **Ptolomeo**          | la Tierra es el centro del universo y que el Sol, la Luna y los planetas giran a su alrededor |
# | 1473 - 1543 | **Nicolás Copérnico** | la Tierra no es el centro del universo                                                        |
# | 1571 - 1630 | **Johannes Kepler**   | los planetas se mueven en órbitas elípticas y no circulares                                   |
# | 1642 - 1727 | **Isaac Newton**      | unificó el cielo y la tierra bajo un mismo conjunto de leyes matemáticas                      |
# | 1879 - 1955 | **Albert Einstein**   | unificó el espacio y el tiempo en una sola entidad: el espacio-tiempo                         |

# %% [markdown]
# ## Qué ha sucedido recientemente ...

# %% [markdown]
# * Los últimos 100 años vieron el surgimiento y consolidación de diferentes teorías formales (entre ellas la lógica y la teoría de los lenguajes formales)
# * Estas teorías cobraron especial importancia en los últimos años por el impacto social de **INTELIGENCIA ARTIFICIAL** y la incidencia de la computación en todos los niveles humanos
# * Para poder entender cómo desarrollar adecuadamente algoritmos complejos y saber cuáles son las limitaciones de las computadoras es necesario entender ciertos conceptos fundacionales que veremos a lo largo de esta materia

# %% [markdown]
# ![af-ai.png](attachment:fd510829-afab-4454-ad86-ae31521125f2.png)

# %% [markdown]
# ## ¿Qué sucede con los símbolos?

# %% [markdown]
# * Los seres humanos han representado el conocimiento usando símbolos desde hace varios milenios
# * El lenguaje escrito es un ejemplo de dicho uso
# * Recientemente en la historia surgió la pregunta: **¿Qué cosas pueden representarse con símbolos? ¿Cuál es el límite?**
# * Esta pregunta cobró especial protagonismo con el surgimiento de las computadoras electrónicas, que afectaron el comportamiento de toda la civilización humana en las últimas décadas (1980 – actualidad)
# * Esto se intensificó con el advenimiento de Internet ...
# * Para entender los límites y capacidades de usar símbolos, necesitamos **teorías formales** que nos ayuden a entenderlos

# %% [markdown]
# ## Concepto de Lenguaje Formal

# %% [markdown]
# * Lenguaje definido sobre un alfabeto $\Sigma$ a todo subconjunto de $\Sigma^*$
# * Ejemplo: sea $\Sigma = \{a, b, c\}$. Entonces:
#     * $L = \{bc, cabcc\}$ es un lenguaje finito
#     * $L = a^*$ es infinito
#     * $L = a^* b^*$ también
#     * $L = \{a^n b^n / n>0\}$ también lo es

# %% [markdown]
# ![lf.png](attachment:53f0601e-6a51-4d81-a0ef-30fecd005abd.png)

# %% [markdown]
# ## ¿Qué sucede con los símbolos?

# %% [markdown]
# ![simbolos.png](attachment:1518b962-e704-4a37-ae9e-eae14e51e4c1.png)

# %% [markdown]
# * **Un alfabeto**: conjunto finito de símbolos
# * **Una palabra o cadena**: secuencia finito de símbolos
# * **Un lenguaje**: un conjunto (finito o infinito) de palabras
#
# **Preguntas:**
# **¿qué relación hay entre las máquinas y los lenguajes?**
# **¿puedo reconocer con una máquina si una cadena w pertenece a un lenguaje L?**
