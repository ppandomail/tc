# %% [markdown]
# # Redes de Petri (PN)
# ---

# %% [markdown]
# * Inventado por Carl Petri en 1939, publicado en 1962
# * Modelo gráfico, matemático, formal y abstracto
# * Describir y analizar el flujo de información
# * Se caracteriza por la concurrencia, sincronización, exclusión mutua y conflictos
# * Puede modelarse un sistema de evolución en paralelo o eventos concurrentes compuesto de varios procesos que cooperan para la realización de un objetivo común

# %% [markdown]
# ## Aplicaciones

# %% [markdown]
# * Sistema de producción
# * Robótica
# * Cómputo paralelo
# * Autómatas

# %% [markdown]
# ## Componentes

# %% [markdown]
# * lugares
# * transiciones
# * arcos dirigidos
# * marcas (recursos) que ocupan posiciones dentro de los lugares

# %% [markdown]
# ## Reglas

# %% [markdown]
# * Los arcos conectan un lugar a una transición así como una transición a un lugar
# * No puede haber arcos entre lugares ni entre transiciones
# * Los lugares contienen un número finito o infinito contable de marcas
# * Las transiciones se disparan, es decir consumen marcas de una posición de inicio y producen marcas en una posición de llegada
# * Una transición está habilitada si tiene marcas en todas sus posiciones de entrada

# %% [markdown]
# ![pn1.png](attachment:549ff9c0-a302-4060-a147-7f7b5eebdf12.png)

# %% [markdown]
# ## Definición formal

# %% [markdown]
# $$PN <P, T, Pre, Post, M>$$
#
# |       |                                                                         |
# | --    | --                                                                      |
# | $P$   | conjunto finito no vacio de lugares. $P = \{p1, p2, ...\}$              |
# | $T$   | conjunto finito no vacio de transiciones. $T = \{t1, t2, ...\}$         |
# | $Pre$ | aplicación de incidencia previa. $Pre: P$ x $T \rightarrow \mathbb{N}$  |
# | $Post$| aplicación de incidencia previa. $Post: P$ x $T \rightarrow \mathbb{N}$ |
# | $M$   | aplicación de marcado. $M: P \rightarrow \mathbb{N}$                    |

# %% [markdown]
# ![pn2.png](attachment:8680d5c5-9172-4a52-9473-f65f00e18ded.png)

# %% [markdown]
# ![pn3.png](attachment:856ca025-976c-4f97-a924-b8fc15848e83.png)

# %% [markdown]
# ## Ejemplo: sumas

# %% [markdown]
# ![pn4.png](attachment:92423562-83b8-4d29-b022-e06150912daf.png)

# %% [markdown]
# ## Ejemplo: $L = \{a^n b^m c / n,m, > 0\}$

# %% [markdown]
# ![pn5.png](attachment:bca402fa-4c16-4c8f-b709-5edb4558ff41.png)

# %% [markdown]
# [Más Ejemplos](https://jcastrom.jimdofree.com/matematica/matem%C3%A1tica-discreta/redes-de-petri/)
