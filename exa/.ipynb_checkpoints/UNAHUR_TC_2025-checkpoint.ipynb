# %% [markdown]
# $$\Huge \text{UNIVERSIDAD NACIONAL DE HURLINGHAM}$$
# $$\huge \text{Inst. de Tecnología e Ingeniería}$$
# $$\LARGE \text{TEORIA DE LA COMPUTACIÓN}$$
# $$\Large \text{Prof. Mag. Ing. Pablo Pandolfo}$$
# $$\large 2025$$

# %% [markdown]
# ¿En qué áreas básicas se sustenta la ciencia de la computación?

# %% [markdown]
# ¿Que estudia la teoría de la computabilidad?

# %% [markdown]
# ¿Qué estudia la teoría de la complejidad computacional?

# %% [markdown]
# ¿Qué habilidades pueden adquirir en relación al estudio de los contenidos de la ciencia de la computación?

# %% [markdown]
# ¿Qué es lo que puede limitar las capacidades de las computadoras?

# %% [markdown]
# ¿Cuáles son los recursos más comunes que se estudian en la relación de un cálculo?

# %% [markdown]
# ¿Todos los algoritmos creados pueden representarse en un lenguaje de programación?

# %% [markdown]
# ¿Cuándo se considera que una función es computable?
